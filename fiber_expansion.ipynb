# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from matplotlib import pyplot as plt
from math import ceil
from misc import *

# %%
N_new, N_samples
# Out:
# (2, 101)

# %%
spatial_extent = 12.3
N_samples = 101
a_field = np.random.random((3, N_samples, N_samples))
xCoord = np.linspace(-spatial_extent/2, spatial_extent/2, N_samples)
expanded_extent = 21.0
(new_width, xCoord_new) = array_stretcher(xCoord, expanded_extent)
N_new = len(xCoord_new)
n = N_new - N_samples
a_better_field = sym_pad(a_field, n, mode='constant')

# %%
plot_field = a_better_field[2]
plt.figure()
plt.imshow(plot_field)
plt.show()
